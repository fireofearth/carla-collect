# %% [markdown]
# Test selecting road points and bounding bounding boxes of roads

# %%
import collections
import math

import pytest
import numpy as np
import pandas as pd
import scipy.ndimage
import matplotlib
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cm
import cv2 as cv
import carla

import utility as util
import carlautil

CARLA_HOST = '127.0.0.1'
CARLA_PORT = 2000
DELTA = 0.1
PRECISION = 1.0

# %%
map_name = 'Town03'
client = carla.Client(CARLA_HOST, CARLA_PORT)
client.set_timeout(10.0)
world = client.get_world()
# world = client.load_world(map_name)
carla_map = world.get_map()
traffic_manager = client.get_trafficmanager(8000)
carla_topology = carla_map.get_topology()
spawn_points = carla_map.get_spawn_points()

# %%
def lateral_shift(transform, shift):
    transform.rotation.yaw += 90
    return transform.location + shift * transform.get_forward_vector()

def is_yellow_line(waypoint, shift):
    w = carla_map.get_waypoint(lateral_shift(waypoint.transform, shift), project_to_road=False)
    if w is None:
        return False
    return w.lane_id * waypoint.lane_id < 0

road_polygons = []
white_lines   = []
yellow_lines  = []
topology      = [x[0] for x in carla_map.get_topology()]
topology      = sorted(topology, key=lambda w: w.transform.location.z)
precision     = 0.05
for waypoint in topology:
    waypoints = [waypoint]
    nxt = waypoint.next(precision)[0]
    while nxt.road_id == waypoint.road_id:
        waypoints.append(nxt)
        nxt = nxt.next(precision)[0]

    left_marking  = carlautil.locations_to_ndarray(
            [lateral_shift(w.transform, -w.lane_width * 0.5) for w in waypoints])
    right_marking = carlautil.locations_to_ndarray(
            [lateral_shift(w.transform, w.lane_width * 0.5) for w in waypoints])
    road_polygon = np.concatenate((left_marking, np.flipud(right_marking)), axis=0)

    if len(road_polygon) > 2:
        road_polygons.append(road_polygon)
        if not waypoint.is_intersection:
            sample = waypoints[int(len(waypoints) / 2)]
            if is_yellow_line(sample, -sample.lane_width * 1.1):
                yellow_lines.append(left_marking)
            else:
                white_lines.append(left_marking)
            if is_yellow_line(sample, sample.lane_width * 1.1):
                yellow_lines.append(right_marking)
            else:
                white_lines.append(right_marking)

# %%
# Functions

def render_map(ax, extent, pixels_per_m=3):
    """Render map
    
    Parameters
    ==========
    ax : matplotlib.pyplot.Axes
        The axes to render onto
    extent : tuple of int
        The extent of the map to render of form (x_min, x_max, y_min, y_max) in meters
    pixels_per_m : int
        The number of pixels per meter.
    """
    x_min, x_max, y_min, y_max = extent
    x_size = x_max - x_min
    y_size = y_max - y_min
    dim = (int(pixels_per_m * y_size), int(pixels_per_m * x_size), 3)
    image = np.zeros(dim)

    for polygon in road_polygons:
        rzpoly = ( pixels_per_m*(polygon[:,:2] - np.array([x_min, y_min])) ).astype(int).reshape((-1,1,2))
        cv.fillPoly(image, [rzpoly], (150,150,150))

    for line in white_lines:
        rzline = ( pixels_per_m*(line[:,:2] - np.array([x_min, y_min])) ).astype(int).reshape((-1,1,2))
        cv.polylines(image, [rzline], False, (255,255,255), thickness=2)

    for line in yellow_lines:
        rzline = ( pixels_per_m*(line[:,:2] - np.array([x_min, y_min])) ).astype(int).reshape((-1,1,2))
        cv.polylines(image, [rzline], False, (255,255,0), thickness=2)

    image = image.astype(np.uint8).swapaxes(0,1)
    ax.imshow(image.swapaxes(0,1), extent=extent, origin='lower', interpolation='none')

def to_point(wp):
    x, y, _ = carlautil.to_location_ndarray(wp)
    return [x, y]
    
def get_adjacent_waypoints(start_wp):
    """Get the adjacent lanes on the waypoint going in the same direction on the road.
    
    Parameters
    ==========
    start_wp : carla.Waypoint
        Starting waypoint to get adjacent waypoints from.
    
    Returns
    =======
    list of carla.Waypoint
        Waypoints ordered [--left lanes--, start_wp, --right lanes--].
    """
    lane_sgn = util.sgn(start_wp.lane_id)
    def should_select(wp):
        if wp is None:
            return False
        if wp.lane_type != carla.LaneType.Driving:
            return False
        if util.sgn(wp.lane_id) != lane_sgn:
            return False
        return True
    rlanes = list()
    wp = start_wp
    while True:
        wp = wp.get_right_lane()
        if not should_select(wp):
            break
        rlanes.append(wp)
    llanes = list()
    wp = start_wp
    while True:
        wp = wp.get_left_lane()
        if not should_select(wp):
            break
        llanes.append(wp)
    return util.reverse_list(llanes) + [start_wp] + rlanes

def get_straight_line(start_wp, start_yaw, tol=2.0):
    x_start, y_start, _ = carlautil.to_location_ndarray(start_wp)
    FACTOR = 10
    x_end, y_end = x_start + FACTOR * np.cos(start_yaw), y_start + FACTOR * np.sin(start_yaw)
    
    def inner(wp):
        wps = wp.next_until_lane_end(PRECISION)
        points = np.array(util.map_to_ndarray(to_point, wps))
        distances = util.distances_from_line_2d(points, x_start, y_start, x_end, y_end)
        wps_mask = np.nonzero(distances > tol)[0]
        if wps_mask.size > 0:
            # waypoints veer off a straight line
            idx = wps_mask[0]
            return points[:idx], list()
        else:
            # waypoints stay one straight line. Get the next set of waypoints
            return points, wps[-1].next(PRECISION)
    
    dq = collections.deque([start_wp])
    point_collection = []
    while len(dq) > 0:
        wp = dq.popleft()
        points, next_wps = inner(wp)
        # print(util.map_to_list(lambda wp: wp.lane_type, next_wps))
        dq.extend(next_wps)
        point_collection.append(points)
    return np.concatenate(point_collection)

def get_straight_lanes(start_wp, tol=2.0):
    _, start_yaw, _ = carlautil.to_rotation_ndarray(start_wp)
    wps = get_adjacent_waypoints(start_wp)
    f = lambda wp: get_straight_line(wp, start_yaw, tol=tol)
    return np.concatenate(util.map_to_list(f, wps))

def get_road_segment_enclosure(start_wp, tol=2.0):
    _, start_yaw, _ = carlautil.to_rotation_ndarray(start_wp)
    adj_wps = get_adjacent_waypoints(start_wp)
    # mtx : np.array
    #   Rotation matrix from world coordinates, both frames in UE orientation
    mtx = util.rotation_2d(-start_yaw)
    # rev_mtx : np.array
    #   Rotation matrix to world coordinates, both frames in UE orientation
    rev_mtx = util.rotation_2d(start_yaw)
    s_x, s_y, _ = carlautil.to_location_ndarray(start_wp)

    # Get points of lanes
    f = lambda wp: get_straight_line(wp, start_yaw, tol=tol)
    pc = util.map_to_list(f, adj_wps)
    
    # Get length of bb for lanes
    def g(points):
        points = points - np.array([s_x, s_y])
        points = (rev_mtx @ points.T)[0]
        return np.abs(np.max(points) - np.min(points))
    lane_lengths = util.map_to_ndarray(g, pc)
    length = np.min(lane_lengths)

    # Get width of bb for lanes
    lwp, rwp = adj_wps[0], adj_wps[-1]
    l_x, l_y, _ = carlautil.to_location_ndarray(lwp)
    r_x, r_y, _ = carlautil.to_location_ndarray(rwp)
    points = np.array([[l_x, l_y], [s_x, s_y], [r_x, r_y]])
    points = points @ rev_mtx.T
    l_width = np.abs(points[0, 1] - points[1, 1]) + lwp.lane_width / 2.
    r_width = np.abs(points[1, 1] - points[2, 1]) + rwp.lane_width / 2.

    # construct bounding box of road segment
    x, y, _ = carlautil.to_location_ndarray(start_wp)
    vec = np.array([[0,0], [-2, 0]]) @ mtx.T
    dx0, dy0 = vec[1, 0], vec[1, 1]
    vec = np.array([[0,0], [length, 0]]) @ mtx.T
    dx1, dy1 = vec[1, 0], vec[1, 1]
    vec = np.array([[0,0], [0, -l_width]]) @ mtx.T
    dx2, dy2 = vec[1, 0], vec[1, 1]
    vec = np.array([[0,0], [0, r_width]]) @ mtx.T
    dx3, dy3 = vec[1, 0], vec[1, 1]
    return np.array([
            [x + dx0 + dx3, y + dy0 + dy3],
            [x + dx1 + dx3, y + dy1 + dy3],
            [x + dx1 + dx2, y + dy1 + dy2],
            [x + dx0 + dx2, y + dy0 + dy2]])

# %%
fig, ax = plt.subplots(figsize=(20,20))

for poly in road_polygons:
    patch = matplotlib.patches.Polygon(poly[:, :2], fill=True, color='grey')
    ax.add_patch(patch)
for line in yellow_lines:
    ax.plot(line.T[0], line.T[1], c='yellow', linewidth=2)
for line in white_lines:
    ax.plot(line.T[0], line.T[1], c='white', linewidth=2)

for idx, sp in enumerate(spawn_points):
    spp = carla.Transform(
            sp.location - 2.5 * sp.get_forward_vector(),
            sp.rotation)
    x, y, _ = carlautil.to_location_ndarray(spp)
    _, yaw, _ = carlautil.to_rotation_ndarray(sp)
    ax.text(x, y, str(idx), color='orange', size=13, rotation=np.rad2deg(yaw))
    x, y, _ = carlautil.to_location_ndarray(sp)
    ax.arrow(x, y, 3*np.cos(yaw), 3*np.sin(yaw), width=0.4, color='orange')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_aspect('equal')
ax.set_facecolor('black')
fig.tight_layout()

# %%
# Getting straight lanes
TOL = 2.0
starting_point = 99
sp = spawn_points[starting_point]
wp = carla_map.get_waypoint(sp.location)

fig, axes = plt.subplots(2,1, figsize=(10, 3))
axes = axes.ravel()

# Programmically create enclosure
points = get_straight_lanes(wp, tol=TOL)
axes[1].plot(sp.location.x, sp.location.y, '*')
axes[1].scatter(points[:,0], points[:,1], c='r', s=2)
bbox = get_road_segment_enclosure(wp, tol=TOL)
patch = patches.Polygon(bbox, ec='b', fc='none')
axes[1].add_patch(patch)
axes[1].set_title("Programmically create enclosure")
axes[1].set_aspect('equal')

# Programmically collect some lane points
wps = wp.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-ro')

wp = wps[-1]
intersect_wps = wp.next(PRECISION)
wp1, wp2 = intersect_wps

wps = wp2.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-go')

wps = wp1.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-bo')

wp = wps[-1]
intersect_wps = wp.next(PRECISION)
wp1 = intersect_wps[0]

wps = wp1.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-yo')
axes[0].set_title("Programmically collect some lane points")
axes[0].set_aspect('equal')

# %%
# Demonstrate how to get lengths and widths of road
# Demonstrate how to gen road enclosure
starting_point = 99
sp = spawn_points[starting_point]
wp = carla_map.get_waypoint(sp.location)
_, start_yaw, _ = carlautil.to_rotation_ndarray(wp)

fig, axes = plt.subplots(2, 1, figsize=(10, 5))
axes = axes.ravel()

start_wp = wp
TOL=1.0
_, start_yaw, _ = carlautil.to_rotation_ndarray(start_wp)
adj_wps = get_adjacent_waypoints(start_wp)
mtx = util.rotation_2d(-start_yaw)

# Get points of lanes
f = lambda wp: get_straight_line(wp, start_yaw, tol=TOL)
pc = util.map_to_list(f, adj_wps)

# Get length of bb for lanes
def g(points):
    points = (mtx @ points.T)[0]
    return np.max(points) - np.min(points)
lane_lengths = util.map_to_ndarray(g, pc)
length = np.min(lane_lengths)

# Get width of bb for lanes
lwp, rwp = adj_wps[0], adj_wps[-1]
s_x, s_y, _ = carlautil.to_location_ndarray(start_wp)
l_x, l_y, _ = carlautil.to_location_ndarray(lwp)
r_x, r_y, _ = carlautil.to_location_ndarray(rwp)
points = np.array([[l_x, l_y], [s_x, s_y], [r_x, r_y]])
points = points @ mtx.T
l_width = np.abs(points[0, 1] - points[1, 1]) + lwp.lane_width / 2.
r_width = np.abs(points[1, 1] - points[2, 1]) + rwp.lane_width / 2.

x, y, _ = carlautil.to_location_ndarray(start_wp)
axes[1].plot(x, y, '*')

points = get_straight_lanes(wp, tol=2.0)
axes[1].scatter(points[:,0], points[:,1], c='r', s=2)

# longitudinal direction in local coordinate frame points along +x-axis
x, y, _ = carlautil.to_location_ndarray(start_wp)
vec = (mtx @ np.array([[0,0], [length, 0]]).T).T
dx, dy = vec[1, 0], vec[1, 1]
axes[1].plot([x, x + dx], [y, y + dy], '-bo')

# left direction in local coordinate frame points along -y-axis
x, y, _ = carlautil.to_location_ndarray(start_wp)
vec = (mtx @ np.array([[0,0], [0, -l_width]]).T).T
dx, dy = vec[1, 0], vec[1, 1]
axes[1].plot([x, x + dx], [y, y + dy], '-bo')

# right direction in local coordinate frame points along +y-axis
x, y, _ = carlautil.to_location_ndarray(start_wp)
vec = (mtx @ np.array([[0,0], [0, r_width]]).T).T
dx, dy = vec[1, 0], vec[1, 1]
axes[1].plot([x, x + dx], [y, y + dy], '-bo')
axes[1].set_title("Construct wire frame of road segment")
axes[1].set_aspect('equal')

# construct bounding box of road segment
x, y, _ = carlautil.to_location_ndarray(start_wp)
vec = np.array([[0,0], [length, 0]]) @ mtx.T
dx1, dy1 = vec[1, 0], vec[1, 1]
vec = np.array([[0,0], [0, -l_width]]) @ mtx.T
dx2, dy2 = vec[1, 0], vec[1, 1]
vec = np.array([[0,0], [0, r_width]]) @ mtx.T
dx3, dy3 = vec[1, 0], vec[1, 1]
bbox = np.array([
        [x + dx3, y + dy3],
        [x + dx1 + dx3, y + dy1 + dy3],
        [x + dx1 + dx2, y + dy1 + dy2],
        [x + dx2, y + dy2]])
patch = patches.Polygon(bbox, ec='b', fc='none')
axes[0].add_patch(patch)

# Programmically select straight lane points
points = get_straight_lanes(wp, tol=TOL)
axes[0].plot(sp.location.x, sp.location.y, '*')
axes[0].scatter(points[:,0], points[:,1], c='r', s=2)
axes[0].set_title("Construct enclosure to road")
axes[0].set_aspect('equal')

# %%
# Collecting points on diagonal road
TOL = 2.0

fig, axes = plt.subplots(1,3, figsize=(12,6))
axes = axes.ravel()

sp = spawn_points[90]
wp = carla_map.get_waypoint(sp.location)

wps = wp.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-ro')

wp = wps[-1]
intersect_wps = wp.next(PRECISION)
wp1 = intersect_wps[0]

wps = wp1.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-yo')

sp = spawn_points[91]
wp = carla_map.get_waypoint(sp.location)

wps = wp.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-bo')

wp = wps[-1]
intersect_wps = wp.next(PRECISION)
wp1 = intersect_wps[0]

wps = wp1.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-go')
axes[0].set_aspect('equal')

# Programmically create enclosure
sp = spawn_points[90]
wp = carla_map.get_waypoint(sp.location)
points = get_straight_lanes(wp, tol=TOL)
axes[1].plot(sp.location.x, sp.location.y, '*')
axes[1].scatter(points[:,0], points[:,1], c='r', s=2)

# bbox = get_road_segment_enclosure(wp, tol=TOL)
# patch = patches.Polygon(bbox, ec='b', fc='none')
# axes[1].add_patch(patch)

start_wp = wp
_, start_yaw, _ = carlautil.to_rotation_ndarray(start_wp)
adj_wps = get_adjacent_waypoints(start_wp)
mtx = util.rotation_2d(-start_yaw)

# Get points of lanes
f = lambda wp: get_straight_line(wp, start_yaw, tol=TOL)
pc = util.map_to_list(f, adj_wps)
print(util.map_to_list(lambda p: p.shape, pc))
s_x, s_y, _ = carlautil.to_location_ndarray(start_wp)
rev_mtx = util.rotation_2d(start_yaw)

# Get length of bb for lanes
def g(points):
    points = points - np.array([s_x, s_y])
    rot_points = rev_mtx @ points.T
    axes[2].scatter(rot_points[0], rot_points[1])
    points = rot_points[0]
    return np.max(points) - np.min(points)
lane_lengths = util.map_to_ndarray(g, pc)
length = np.min(lane_lengths)
print(lane_lengths)

axes[2].set_aspect('equal')

# Get width of bb for lanes
lwp, rwp = adj_wps[0], adj_wps[-1]
l_x, l_y, _ = carlautil.to_location_ndarray(lwp)
r_x, r_y, _ = carlautil.to_location_ndarray(rwp)
points = np.array([[l_x, l_y], [s_x, s_y], [r_x, r_y]])
points = points @ rev_mtx.T
l_width = np.abs(points[0, 1] - points[1, 1]) + lwp.lane_width / 2.
r_width = np.abs(points[1, 1] - points[2, 1]) + rwp.lane_width / 2.

# construct bounding box of road segment
x, y, _ = carlautil.to_location_ndarray(start_wp)
vec = np.array([[0,0], [-2, 0]]) @ mtx.T
dx0, dy0 = vec[1, 0], vec[1, 1]
vec = np.array([[0,0], [length, 0]]) @ mtx.T
dx1, dy1 = vec[1, 0], vec[1, 1]
vec = np.array([[0,0], [0, -l_width]]) @ mtx.T
dx2, dy2 = vec[1, 0], vec[1, 1]
vec = np.array([[0,0], [0, r_width]]) @ mtx.T
dx3, dy3 = vec[1, 0], vec[1, 1]
bbox = np.array([
        [x + dx0 + dx3, y + dy0 + dy3],
        [x + dx1 + dx3, y + dy1 + dy3],
        [x + dx1 + dx2, y + dy1 + dy2],
        [x + dx0 + dx2, y + dy0 + dy2]])

patch = patches.Polygon(bbox, ec='b', fc='none')
axes[1].add_patch(patch)
axes[1].set_title("Programmically create enclosure")
axes[1].set_aspect('equal')
# Out:
# [(36, 2), (32, 2)]
# [35.68534047 29.77244007]

# %%
# Demonstrate how to separate lane points into straight and curved portions
TOL = 2.0
starting_point = 130
sp = spawn_points[starting_point]
wp = carla_map.get_waypoint(sp.location)

fig, axes = plt.subplots(1, 2, figsize=(12,12))
axes = axes.ravel()

# Programmically create enclosure
points = get_straight_lanes(wp, tol=TOL)
axes[1].plot(sp.location.x, sp.location.y, '*')
axes[1].scatter(points[:,0], points[:,1], c='r', s=2)
bbox = get_road_segment_enclosure(wp, tol=TOL)
patch = patches.Polygon(bbox, ec='b', fc='none')
axes[1].add_patch(patch)
axes[1].set_title("Programmically create enclosure")
axes[1].set_aspect('equal')

# Programmically collect some lane points
wps = wp.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-ro')

# Manually separate straight line from curved line with tolerance
wp = wps[-1]
intersect_wps = wp.next(PRECISION)
wp = intersect_wps[0]
start_wp = wp
wps = start_wp.next_until_lane_end(PRECISION)
x_start, y_start, _ = carlautil.to_location_ndarray(start_wp)
_, yaw_start, _ = carlautil.to_rotation_ndarray(start_wp)
x_end, y_end = x_start + np.cos(yaw_start), y_start + np.sin(yaw_start)
points = np.array(util.map_to_ndarray(to_point, wps))
distances = np.abs((x_end - x_start)*(y_start - points[:, 1]) - (x_start - points[:, 0])*(y_end - y_start)) \
        / np.sqrt((x_end - x_start)**2 + (y_end - y_start)**2)
mask = np.nonzero(distances > TOL)[0]
idx = mask[0]

axes[0].plot(points[:idx,0], points[:idx,1], '-ro')
axes[0].plot(points[idx:,0], points[idx:,1], '-bo')
axes[0].set_title("Programmically collect some lane points")
axes[0].set_aspect('equal')

# %%
# Getting straight lanes
TOL=2.0
starting_point = 220
starting_point = 221
sp = spawn_points[starting_point]
wp = carla_map.get_waypoint(sp.location)

fig, axes = plt.subplots(1, 2, figsize=(10, 10))
axes = axes.ravel()

# Programmically create enclosure
points = get_straight_lanes(wp, tol=TOL)
axes[1].plot(sp.location.x, sp.location.y, '*')
axes[1].scatter(points[:,0], points[:,1], c='r', s=2)
bbox = get_road_segment_enclosure(wp, tol=TOL)
patch = patches.Polygon(bbox, ec='b', fc='none')
axes[1].add_patch(patch)
axes[1].set_title("Programmically create enclosure")
axes[1].set_aspect('equal')

# Programmically collect some lane points
wps = wp.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-ro')

wp = wps[-1]
intersect_wps = wp.next(PRECISION)
wp = intersect_wps[0]
wps = wp.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-ro')

wp = wps[-1]
intersect_wps = wp.next(PRECISION)
wp1, wp2 = intersect_wps

wps = wp2.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-go')

wps = wp1.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-bo')

wp = wps[-1]
intersect_wps = wp.next(PRECISION)
wp1 = intersect_wps[0]

wps = wp1.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-yo')
axes[0].set_title("Programmically collect some lane points")
axes[0].set_aspect('equal')

# %%
# Getting straight lanes
starting_point = 99
sp = spawn_points[starting_point]
wp = carla_map.get_waypoint(sp.location)

fig, axes = plt.subplots(2,1, figsize=(10, 5))
axes = axes.ravel()

# Programmically select straight lane points
points = get_straight_lanes(wp, tol=5.0)
axes[1].plot(sp.location.x, sp.location.y, '*')
axes[1].scatter(points[:,0], points[:,1], c='r')
axes[1].set_title("Programmically select straight lane points")
axes[1].set_aspect('equal')

# Programmically collect some lane points
wps = wp.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-ro')

wp = wps[-1]
intersect_wps = wp.next(PRECISION)
wp1, wp2 = intersect_wps

wps = wp2.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-go')

wps = wp1.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-bo')

wp = wps[-1]
intersect_wps = wp.next(PRECISION)
wp1 = intersect_wps[0]

wps = wp1.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-yo')
axes[0].set_title("Programmically collect some lane points")
axes[0].set_aspect('equal')

# %%
# Getting straight lanes
starting_point = 164
sp = spawn_points[starting_point]
wp = carla_map.get_waypoint(sp.location)

fig, axes = plt.subplots(2,1, figsize=(10, 5))
axes = axes.ravel()

# Programmically select straight lane points
points = get_straight_lanes(wp, tol=5.0)
axes[1].plot(sp.location.x, sp.location.y, '*')
axes[1].scatter(points[:,0], points[:,1], c='r')
axes[1].set_title("Programmically select straight lane points")
axes[1].set_aspect('equal')

# Programmically collect some lane points
wps = wp.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-ro')

wp = wps[-1]
intersect_wps = wp.next(PRECISION)
wp1 = intersect_wps[0]

wps = wp1.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-bo')
axes[0].set_title("Programmically collect some lane points")
axes[0].set_aspect('equal')

# %%
# Getting straight lanes
TOL=2.0
starting_point = 89
sp = spawn_points[starting_point]
wp = carla_map.get_waypoint(sp.location)

fig, axes = plt.subplots(2,1, figsize=(10, 5))
axes = axes.ravel()

# Programmically create enclosure
points = get_straight_lanes(wp, tol=TOL)
axes[1].plot(sp.location.x, sp.location.y, '*')
axes[1].scatter(points[:,0], points[:,1], c='r', s=2)
bbox = get_road_segment_enclosure(wp, tol=TOL)
patch = patches.Polygon(bbox, ec='b', fc='none')
axes[1].add_patch(patch)
axes[1].set_title("Programmically create enclosure")
axes[1].set_aspect('equal')

# Programmically collect some lane points
wps = wp.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-bo')

wp = wps[-1]
intersect_wps = wp.next(PRECISION)
wp1, wp2 = intersect_wps

wps = wp2.next_until_lane_end(PRECISION)
points = util.map_to_ndarray(to_point, wps)
axes[0].plot(points[:,0], points[:,1], '-bo')

wp = wp1
for _ in range(10):
    wps = wp.next_until_lane_end(PRECISION)
    points = util.map_to_ndarray(to_point, wps)
    axes[0].plot(points[:,0], points[:,1], '-bo')

    wp = wps[-1]
    intersect_wps = wp.next(PRECISION)
    wp = intersect_wps[0]

axes[0].set_title("Programmically collect some lane points")
axes[0].set_aspect('equal')

# %%
# Demonstrate getting adjacent waypoints 
starting_point = 89
sp = spawn_points[starting_point]
start_wp = carla_map.get_waypoint(sp.location)
print('start waypoint', start_wp.id, start_wp.lane_id, start_wp.road_id, start_wp.lane_type)

print('getting waypoints on the right')
rwp = start_wp
for _ in range(4):
    rwp = rwp.get_right_lane()
    print('              ', rwp.id, rwp.lane_id, rwp.road_id, rwp.lane_type)

print('getting waypoints on the left')
lwp = start_wp
for _ in range(4):
    lwp = lwp.get_left_lane()
    print('              ', lwp.id, lwp.lane_id, lwp.road_id, lwp.lane_type)


wps = get_adjacent_waypoints(start_wp)
print('get_adjacent_waypoints()')
for wp in wps:
    print(wp.id, wp.lane_id, wp.road_id, wp.lane_type)
# Out:
# start waypoint 3668103578437783356 -1 47 Driving
# getting waypoints on the right
#                10756131507643646290 -2 47 Parking
#                13839131702601028436 -3 47 Shoulder
#                11639129993972932131 -4 47 Sidewalk
#                5616527008650884851 -5 47 Sidewalk
# getting waypoints on the left
#                8748412695128961633 1 47 Driving
#                3668103578437783356 -1 47 Driving
#                8748412695128961633 1 47 Driving
#                3668103578437783356 -1 47 Driving
# get_adjacent_waypoints()
# 3668103578437783356 -1 47 Driving

# %%
# Get rectangle bitmap from 
x_min  = 50
x_max  = 220
y_min  = 30
y_max  = 90    
TOL=2.0
starting_point = 89
sp = spawn_points[starting_point]
wp = carla_map.get_waypoint(sp.location)

fig, ax = plt.subplots(figsize=(8,8))
extent = (x_min, x_max, y_min, y_max)
render_map(ax, extent)

# Programmically create enclosure
points = get_straight_lanes(wp, tol=TOL)
ax.plot(sp.location.x, sp.location.y, '*')
ax.scatter(points[:,0], points[:,1], c='r', s=2)
bbox = get_road_segment_enclosure(wp, tol=TOL)
patch = patches.Polygon(bbox, ec='b', fc='none')
ax.add_patch(patch)
ax.set_title("Programmically create enclosure")

None

# %%
x_min  = -150
x_max  = -80
y_min  = 0
y_max  = 80
TOL = 2.0

starting_point = 90
# starting_point = 254
# starting_point = 255
sp = spawn_points[starting_point]
wp = carla_map.get_waypoint(sp.location)

fig, ax = plt.subplots(figsize=(8,8))
extent = (x_min, x_max, y_min, y_max)
render_map(ax, extent)

# Programmically create enclosure
points = get_straight_lanes(wp, tol=TOL)
ax.plot(sp.location.x, sp.location.y, '*')
ax.scatter(points[:,0], points[:,1], c='r', s=2)
bbox = get_road_segment_enclosure(wp, tol=TOL)
patch = patches.Polygon(bbox, ec='b', fc='none')
ax.add_patch(patch)
ax.set_title("Programmically create enclosure")

None
